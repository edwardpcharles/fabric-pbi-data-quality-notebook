# %% [markdown]
# # Data Quality - Shared Config Notebook
#
# Run this notebook from other notebooks using `%run data_quality_config_notebook`.
#
# Edit values here to control environment and runtime settings globally.

# %%
# Environment
LAKEHOUSE_NAME = "MyLakehouse"
SCHEMA_NAME = "data_quality"

# Validation and retry behavior
DELTA_PCT_THRESHOLD = 0.01
MAX_RETRY_ATTEMPTS = 3
INITIAL_RETRY_DELAY = 2
DAX_TIMEOUT_SECONDS = 60

# Maintenance behavior
RUN_TABLE_MAINTENANCE = False
MAINTENANCE_DAY_UTC = 6

FULL_SCHEMA = f"{LAKEHOUSE_NAME}.{SCHEMA_NAME}"
print(f"Loaded shared config for {FULL_SCHEMA}")
